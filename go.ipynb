# %%
import pandas as pd

# %%
go = pd.read_csv('analysis.csv', sep = ',')
go=go.iloc[6:]
go[['go_function','go_ID']]=go['Analysis Type:'].str.split('GO:',1,expand=True)
go['go_ID']=go['go_ID'].str[:-1]
go['go_ID'] = 'GO:' + go['go_ID'].astype(str)
go
# Out:
#                                          Analysis Type:  \
# 6              dTTP diphosphatase activity (GO:0036218)
# 7                            TRAIL binding (GO:0045569)
# 8                         syndecan binding (GO:0045545)
# 9                        glutamate binding (GO:0016595)
# 10    fibroblast growth factor-activated receptor ac...
# ...                                                 ...
# 4898  D-serine transmembrane transporter activity (G...
# 4899        interleukin-9 receptor binding (GO:0005140)
# 4900                   bicarbonate binding (GO:0071890)
# 4901        interleukin-7 receptor binding (GO:0005139)
# 4902        interleukin-3 receptor binding (GO:0005135)
#
#      PANTHER Overrepresentation Test (Released 20220202) Unnamed: 2  \
# 6                                                     5           5
# 7                                                     5           5
# 8                                                     5           5
# ...

# %%
go.to_csv("go_function.csv")

# %%
go['go_ID'][:2000].to_csv('tem.csv')
